# %% [markdown]
# # Import

# %%
train = pd.read_csv('datasets/train.csv', na_values = "", keep_default_na = False)
train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e161f52bc5d7> in <module>
# ----> 1 train = pd.read_csv('datasets/train.csv', na_values = "", keep_default_na = False)
#       2 train
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # Prediction & Submission

# %%
## load test data
test = pd.read_csv('datasets/test.csv', na_values = "", keep_default_na = False)
test
# Out:
#      Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0     2127  907135180           20        RL          60.0      8070   Pave
# 1      193  903206120           75        RL           NaN      7793   Pave
# 2     2407  528181040          120        RL          40.0      6792   Pave
# 3       46  528175010          120        RL          44.0      6371   Pave
# 4     2478  531379030           60        RL          70.0      8304   Pave
# ..     ...        ...          ...       ...           ...       ...    ...
# 728    453  528174060          120        RL          34.0      5381   Pave
# 729   1352  903400180           50        RL          64.0     13053   Pave
# 730    197  903227150           50        RM          53.0      6360   Pave
# 731   2850  909250070           70        RL          43.0      7000   Pave
# 732   2869  909425180           20        RL          80.0     12984   Pave
#
#     Alley Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC  Fence  \
# 0     NaN       Reg          Lvl  ...            0         0     NaN    NaN
# 1     NaN       IR1          Bnk  ...            0         0     NaN    NaN
# 2     NaN       IR1          Lvl  ...            0         0     NaN    NaN
# 3     NaN       IR1          Lvl  ...            0         0     NaN    NaN
# 4     NaN       IR1          Lvl  ...            0         0     NaN  GdPrv
# ..    ...       ...          ...  ...          ...       ...     ...    ...
# 728   NaN       IR1          Lvl  ...            0         0     NaN    NaN
# 729  Pave       Reg          Bnk  ...          220         0     NaN    NaN
# 730   NaN       Reg          Lvl  ...          148         0     NaN    NaN
# 731   NaN       Reg          Lvl  ...            0         0     NaN  MnPrv
# 732   NaN       Reg          Bnk  ...            0         0     NaN    NaN
#
#     Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  Sale Condition
# 0            NaN        0       8    2007        WD           Normal
# 1            NaN        0       5    2010        WD           Normal
# 2            NaN        0       3    2006        New         Partial
# 3            NaN        0       6    2010        New         Partial
# 4            NaN        0       7    2006        WD           Normal
# ..           ...      ...     ...     ...        ...             ...
# 728          NaN        0       8    2009        WD           Normal
# 729          NaN        0       6    2008        WD           Normal
# 730          NaN        0       3    2010        WD           Normal
# 731          NaN        0       5    2006        WD           Normal
# 732          NaN        0       3    2006        WD           Normal
#
# [733 rows x 81 columns]

# %%
preds_test = idiot_model(test)
preds_test[:10]
# Out:
# [100, 100, 100, 100, 100, 100, 100, 100, 100, 100]

# %%
## create dataframe with "Order" and prediction
pred_df = pd.DataFrame({'Order':test['Order'], 'SalePrice':preds_test})
pred_df
# Out:
#      Order  SalePrice
# 0     2127        100
# 1      193        100
# 2     2407        100
# 3       46        100
# 4     2478        100
# ..     ...        ...
# 728    453        100
# 729   1352        100
# 730    197        100
# 731   2850        100
# 732   2869        100
#
# [733 rows x 2 columns]

# %%
## save to csv file for submission
## index = False
pred_df.to_csv('submission.csv', index=False)
